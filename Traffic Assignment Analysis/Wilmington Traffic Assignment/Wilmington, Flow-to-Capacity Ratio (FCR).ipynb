# %%
import pandas as pd
import geopandas as gpd
import folium
from folium import Map, GeoJson
from branca.colormap import linear
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize  # Import Normalize
import matplotlib.cm as cm  # Import colormap
from shapely.wkt import loads
import numpy as np

# %%
import os

TR = [0.2,1,2]
DR = [0.4,0.75,1]
FF = [0.5,0.6]
PF = [0.7,0.8]

dir = 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County'
flow_file_path = dir + '/Flows and logs'
save_path = dir + '/Visualisation_Hyde_County'
link_source = 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/data'
if not os.path.exists(save_path):
    os.makedirs(save_path)

for ix in range(0,len(TR)):
    for jx in range(0,len(DR)):
        for kx in range(0,len(FF)):
            for lx in range(0,len(PF)):
                sp = 'HD_TR'+str(TR[ix])+'_DR'+str(DR[jx])+'_FF'+str(FF[kx])+'_PF'+str(PF[lx])
                print(sp)
                try:
                    # File paths
                    flow_file = flow_file_path+'/'+sp+'_flows.txt'
                    link_file = link_source + '/'+str(TR[ix])+'m/link.csv'
                    net_file =  dir+'/'+sp+'_net.txt'
                    output_file =  save_path+'/'+sp+'.csv'
                    
                    # Load the link.csv file
                    link_df = pd.read_csv(link_file)
    
                    # Parse the flow.txt file
                    flow_data = {}
                    with open(flow_file, 'r') as f:
                        lines = f.readlines()
                        for i in range(0, len(lines), 2):  # Read every alternate line
                            link, flow_value = lines[i].strip().split(' ')[0], float(lines[i].strip().split(' ')[1])
                            from_id, to_id = map(int, link.strip('()').split(','))
                            flow_data[(from_id, to_id)] = flow_value
    
                    # Map the flow values to the link DataFrame
                    link_df['flow'] = link_df.apply(lambda row: flow_data.get((row['fromID'], row['toID']), 0), axis=1)
                    
                    # Parse the trip.txt file for capacity data
                    capacity_data = {}
                    with open(net_file, 'r') as f:
                        lines = f.readlines()
                        metadata_end = False
                        for line in lines:
                            line = line.strip()
                            if not line or line.startswith('~'):  # Skip empty lines and lines starting with '~'
                                continue
                            if '<END OF METADATA>' in line:
                                metadata_end = True
                                continue
                            if metadata_end:  # Process data rows after metadata
                                parts = line.split()
                                if len(parts) < 3 or not parts[0].isdigit():  # Skip lines that don't have valid data
                                    continue
                                init_node = int(parts[0])
                                term_node = int(parts[1])
                                capacity = float(parts[2])
                                capacity_data[(init_node, term_node)] = capacity
                    
                    # Map the capacity values to the link DataFrame
                    link_df['new_capacity'] = link_df.apply(lambda row: capacity_data.get((row['fromID'], row['toID']), 0), axis=1)
                    
                    
                    # Calculate the Flow Capacity Ratio (FCR)
                    link_df['FCR'] = link_df.apply(lambda row: row['flow'] / row['new_capacity'] if row['new_capacity'] > 0 else 0, axis=1)
                    
                    # Save the updated link.csv file
                    link_df.to_csv(output_file, index=False)
                    
                    print(f"Flow and new_capacity columns added and saved to {output_file}")
                    print('Success\n\n')


                    #### edges by flow
                    # # Load the CSV file into a GeoDataFrame
                    # data = pd.read_csv('path_to_your_file.csv')
                    gdf = gpd.GeoDataFrame(link_df, geometry=gpd.GeoSeries.from_wkt(link_df['geometry']))
                    
                    # Set the CRS if necessary
                    gdf.crs = 'EPSG:4326'
                    
                    # Define a colormap and normalization for flow values
                    norm = Normalize(vmin=gdf['flow'].min(), vmax=gdf['flow'].max())
                    cmap = cm.viridis
                    
                    # Plot the GeoDataFrame
                    fig, ax = plt.subplots(figsize=(12, 8))
                    gdf.plot(ax=ax, color=gdf['flow'].apply(lambda x: cmap(norm(x))), linewidth=2)
                    
                    # Add a colorbar
                    sm = cm.ScalarMappable(cmap=cmap, norm=norm)
                    sm.set_array([])  # You must set an empty array for ScalarMappable
                    cbar = plt.colorbar(sm, ax=ax)
                    cbar.set_label('Flow')
                    
                    # Add titles and labels
                    ax.set_title('Road Segments Colored by Flow', fontsize=16)
                    ax.set_xlabel('Longitude', fontsize=12)
                    ax.set_ylabel('Latitude', fontsize=12)
                    # plt.savefig("./results/byflow_WL_TR0.2_DR0.2_FF0.02_PF0.4.png"
                    # Show the plot
                    plt.show()
                except Exception as E:
                    print(E)
                    print('Combination not valid.')
                    print('\n\n')
# Out:
# HD_TR0.2_DR0.4_FF0.5_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.4_FF0.5_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.4_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.4_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.4_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.4_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.4_FF0.6_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.4_FF0.6_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.75_FF0.5_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.75_FF0.5_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.75_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.75_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.75_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.75_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR0.75_FF0.6_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR0.75_FF0.6_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR1_FF0.5_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR1_FF0.5_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR1_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR1_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR1_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR1_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR0.2_DR1_FF0.6_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR0.2_DR1_FF0.6_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.4_FF0.5_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.4_FF0.5_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.4_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.4_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.4_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.4_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.4_FF0.6_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.4_FF0.6_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.75_FF0.5_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.75_FF0.5_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.75_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.75_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.75_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.75_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR0.75_FF0.6_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR0.75_FF0.6_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR1_FF0.5_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR1_FF0.5_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR1_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR1_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR1_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR1_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR1_DR1_FF0.6_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR1_DR1_FF0.6_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR0.4_FF0.5_PF0.7
# Flow and new_capacity columns added and saved to C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Visualisation_Hyde_County/HD_TR2_DR0.4_FF0.5_PF0.7.csv
# Success
#
#
# HD_TR2_DR0.4_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR2_DR0.4_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR0.4_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR2_DR0.4_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR0.4_FF0.6_PF0.8
# Flow and new_capacity columns added and saved to C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Visualisation_Hyde_County/HD_TR2_DR0.4_FF0.6_PF0.8.csv
# Success
#
#
# HD_TR2_DR0.75_FF0.5_PF0.7
# Flow and new_capacity columns added and saved to C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Visualisation_Hyde_County/HD_TR2_DR0.75_FF0.5_PF0.7.csv
# Success
#
#
# HD_TR2_DR0.75_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR2_DR0.75_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR0.75_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR2_DR0.75_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR0.75_FF0.6_PF0.8
# Flow and new_capacity columns added and saved to C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Visualisation_Hyde_County/HD_TR2_DR0.75_FF0.6_PF0.8.csv
# Success
#
#
# HD_TR2_DR1_FF0.5_PF0.7
# Flow and new_capacity columns added and saved to C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Visualisation_Hyde_County/HD_TR2_DR1_FF0.5_PF0.7.csv
# Success
#
#
# HD_TR2_DR1_FF0.5_PF0.8
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR2_DR1_FF0.5_PF0.8_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR1_FF0.6_PF0.7
# [Errno 2] No such file or directory: 'C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Flows and logs/HD_TR2_DR1_FF0.6_PF0.7_flows.txt'
# Combination not valid.
#
#
#
# HD_TR2_DR1_FF0.6_PF0.8
# Flow and new_capacity columns added and saved to C:/Users/tasni/Equitable-Flood-Impact-main hyde county/Parameters_Hyde_County/Parameters_Hyde_County/Visualisation_Hyde_County/HD_TR2_DR1_FF0.6_PF0.8.csv
# Success

# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, LinearSegmentedColormap
from matplotlib import cm

# Set file paths
base_path = 'C:/Users/tasni/Results_Traffic_Rifa'
Area = 'WL'#options = 'Hyde', 'WL'


##############################################################
flows_path = os.path.join(base_path,Area, "Flows")
logs_path = os.path.join(base_path,Area, "Logs")
net_file_path = os.path.join(base_path,Area,"Nets_Trips")
visualization_path = os.path.join(base_path,Area, "Visualization")

data_paths = {
    "0.2m": os.path.join(base_path,Area,"Data","0.2m","link.csv"),
    "1m": os.path.join(base_path,Area,"Data","1m","link.csv"),
    "2m": os.path.join(base_path,Area,"Data","2m","link.csv"),
}

# Function to load flow data from text files
def load_flow_data(flow_file):
    flow_data = {}
    with open(flow_file, 'r') as f:
        lines = f.readlines()
        for i in range(0, len(lines), 2):  # Read every alternate line
            parts = lines[i].strip().split(' ')
            if len(parts) < 2:
                continue
            link, flow_value = parts[0], float(parts[1])
            from_id, to_id = map(int, link.strip('()').split(','))
            flow_data[(from_id, to_id)] = flow_value
    return flow_data

# Function to load capacity data from network files
def load_capacity_data(net_file):
    capacity_data = {}
    with open(net_file, 'r') as f:
        lines = f.readlines()
        metadata_end = False
        for line in lines:
            line = line.strip()
            if not line or line.startswith('~'):
                continue
            if '<END OF METADATA>' in line:
                metadata_end = True
                continue
            if metadata_end:
                parts = line.split()
                if len(parts) < 3 or not parts[0].isdigit():
                    continue
                init_node = int(parts[0])
                term_node = int(parts[1])
                capacity = float(parts[2])
                capacity_data[(init_node, term_node)] = capacity
    return capacity_data

# Process each dataset (0.2m, 1m, 2m)
for label, link_file in data_paths.items():
    if not os.path.exists(link_file):
        print(f"Skipping {label}, link.csv not found.")
        continue

    print(f"Processing {label} dataset...")

    # Load link data
    link_df = pd.read_csv(link_file)

    # Search for flow and net files in "Flows and logs"
    flow_files = [f for f in os.listdir(flows_path) if f.endswith("_flows.txt")]
    net_files = [f for f in os.listdir(net_file_path) if f.endswith("_net.txt")]
    
    for flow_file in flow_files:
        if any(flow_file.replace("_flows.txt", "") in net for net in net_files):
            net_file = next(net for net in net_files if flow_file.replace("_flows.txt", "") in net)

            # Load flow and capacity data
            flow_data = load_flow_data(os.path.join(flows_path, flow_file))
            capacity_data = load_capacity_data(os.path.join(net_file_path, net_file))

            # Map flow and capacity to the link DataFrame
            link_df['flow'] = link_df.apply(lambda row: flow_data.get((row['fromID'], row['toID']), 0), axis=1)
            link_df['capacity'] = link_df.apply(lambda row: capacity_data.get((row['fromID'], row['toID']), 0), axis=1)

            # Compute Flow-to-Capacity Ratio (FCR)
            link_df['FCR'] = link_df.apply(lambda row: row['flow'] / row['capacity'] if row['capacity'] > 0 else 0, axis=1)

            # Cap values at 5 and normalize between 0 and 5
            link_df['scaled_FCR'] = link_df['FCR'].apply(lambda x: min(x, 1.5))

            # Convert to GeoDataFrame
            gdf = gpd.GeoDataFrame(link_df, geometry=gpd.GeoSeries.from_wkt(link_df['geometry']))
            gdf.crs = 'EPSG:4326'

            # Define color scale (0-1.5: Green, 1.5-3: Yellow, 3-5: Red)
            colors = ['green', 'yellow', 'red']
            cmap = LinearSegmentedColormap.from_list("green_to_red", colors)
            norm = Normalize(vmin=0, vmax=1.5)

            # Plot
            fig, ax = plt.subplots(figsize=(12, 8))
            gdf.plot(
                ax=ax,
                color=gdf['scaled_FCR'].apply(lambda x: cmap(norm(x))),
                linewidth=2
            )

            # Add colorbar
            sm = cm.ScalarMappable(cmap=cmap, norm=norm)
            sm.set_array([])
            cbar = plt.colorbar(sm, ax=ax)
            cbar.set_label('Flow-to-Capacity Ratio (FCR)')

            # Titles and labels
            ax.set_title(f'Road Segments Colored by FCR ({label})', fontsize=16)
            ax.set_xlabel('Longitude', fontsize=12)
            ax.set_ylabel('Latitude', fontsize=12)

            # Save the figure
            output_file = os.path.join(visualization_path, flow_file+'.png')
            plt.savefig(output_file)
            plt.close()

            print(f"Visualization saved: {output_file}")

print("All visualizations complete.")
# Out:
# Processing 0.2m dataset...
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR1_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR1_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR1_FF0.6_PF0.8_flows.txt.png
# Processing 1m dataset...
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR1_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR1_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR1_FF0.6_PF0.8_flows.txt.png
# Processing 2m dataset...
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR0.2_DR1_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR1_DR1_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.4_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.4_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.75_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR0.75_FF0.6_PF0.8_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR1_FF0.5_PF0.7_flows.txt.png
# Visualization saved: C:/Users/tasni/Results_Traffic_Rifa\WL\Visualization\WL_TR2_DR1_FF0.6_PF0.8_flows.txt.png
# All visualizations complete.
